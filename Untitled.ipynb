# %%
for i in range(3):  # 3 утга
    for j in range(4):  # 4 утга
        print("#")
# Out:
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #

# %%
for i in range(5):  # 5 утга
    for j in range(2):  # 2 утга
        for k in range(3):  # 3 утга
            print(i, end="")
        print()
    print()
# Out:
# 000
# 000
#
# 111
# 111
#
# 222
# 222
#
# 333
# 333
#
# 444
# 444

# %%
for i in range(1, 3):      # [1, 2]
    for j in range(2, 5):  # [2, 3, 4]
        print("#", end=" ")
# Out:
# # # # # # #

# %%
for i in range(2):
    for j in range(3):
        print(i, j, end=" ")
    print()
# Out:
# 0 0 0 1 0 2
# 1 0 1 1 1 2

# %%
print(type(print("Hi")))

# %%
print(type(print("Hi")))

# %%
print(type(None))
# Out:
# <class 'NoneType'>

# %%
for i in range(1, 5):
    for j in range(4-i):
        print(end=" ")
    for k in range(1,i*2):
        print("*", end="")
    print()
# Out:
#    *
#   ***
#  *****
# *******

# %%
for in range
